# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
# %config IPCompleter.greedy=True
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import os
import math
from collections import OrderedDict
import json

import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torchvision import datasets, transforms, models

# %% [markdown]
# ## Provide user inputs

# %%
#User Inputs in this notebook (or passed as command line arguments in Command Line Application)
in_arg = {}
in_arg['arch'] = 'vgg16'
in_arg['arch_type'] = 'custom' #To differentiate between adding new layers/activations vs just modifying the output features of existing last layer
NUM_CLASSES = 102 #No of flower species
in_arg['feature_extract'] = True #To identify layers prior to classifer or fc should be frozen
in_arg['hidden_units'] = [1024, 512, 256] #Length indicates number of new layers to be added, value at index indicates number of activations to be added each layer
in_arg['learning_rate'] = 0.003
in_arg['epochs'] = 10
in_arg['save_dir'] = 'checkpoints/'

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets
#data_transforms = 

train_transforms = transforms.Compose([transforms.RandomRotation(30),
                                       transforms.RandomResizedCrop(224),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])])

valid_transforms = transforms.Compose([transforms.Resize(255),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])])

test_transforms = transforms.Compose([transforms.Resize(255),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])])

# TODO: Load the datasets with ImageFolder
#image_datasets = 
train_data = datasets.ImageFolder(train_dir, transform = train_transforms)
valid_data = datasets.ImageFolder(valid_dir, transform = valid_transforms)
test_data = datasets.ImageFolder(test_dir, transform = test_transforms)

# TODO: Using the image datasets and the trainforms, define the dataloaders
#dataloaders
trainloaders = torch.utils.data.DataLoader(train_data, batch_size=64, shuffle = True)
validloaders = torch.utils.data.DataLoader(valid_data, batch_size=64, shuffle = True)
testloaders = torch.utils.data.DataLoader(test_data, batch_size=64)

#Uncomment for testing (small dataset)
# from torch.utils.data.sampler import SubsetRandomSampler
# sampler = torch.utils.data.sampler.SubsetRandomSampler(list(range(10)))
# trainloaders = torch.utils.data.DataLoader(train_data, sampler = sampler, batch_size=64)
# validloaders = torch.utils.data.DataLoader(valid_data, sampler = sampler, batch_size=64)
# testloaders = torch.utils.data.DataLoader(test_data, sampler = sampler, batch_size=64)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# <font color='red'>**Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.</font>

# %%
#Load network as feature detector
#Get pre-trained model specifications and override with classifier portion with user activation units

#Helper function to freeze the layer if feature extracting
def set_parameter_requires_grad(model, feature_extracting):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False

#Build/design the custom model            
def build_custom_models(model_name, model_type, num_classes, feature_extract, hidden_units, use_pretrained=True):
       
    model_ft = getattr(models, model_name)(pretrained = use_pretrained)
    set_parameter_requires_grad(model_ft, feature_extract)
    if model_name == 'resnet18':
        in_features = model_ft.fc.in_features
    else:
        try: #Is there an iterable classifier layer for the model chosen?
            iter(model_ft.classifier)
        except TypeError: #If no, choose the classifier layer with no index
            in_features = model_ft.classifier.in_features
        else:
            try: #If yes, check if first index has in_features attribute
                in_features = model_ft.classifier[0].in_features
            except AttributeError: #If No, check if second index has in_features attribute
                in_features = model_ft.classifier[1].in_features
        
    hidden_layers = [in_features] + hidden_units
    layer_builder = (
        lambda i, v : (f"fc{i}", nn.Linear(hidden_layers[i-1], v)),
        lambda i, v: (f"relu{i}", nn.ReLU()),
        lambda i, v: (f"drop{i}", nn.Dropout())        
    )
    
    layers = [f(i, v) for i, v in enumerate(hidden_layers) if i > 0 for f in layer_builder]
    layers += [('fc_final', nn.Linear(hidden_layers[-1], num_classes)),
               ('output', nn.LogSoftmax(dim=1))]    

    if model_name == 'resnet18':
        fc = nn.Sequential(OrderedDict(layers))
        model_ft.fc = fc
    else:
        classifier = nn.Sequential(OrderedDict(layers))
        model_ft.classifier = classifier
#     print("AFTER")
#     print(model.classifier)
    
    return model_ft

# %%
#Instantiate the model and move to GPU/CPU
model_ft = build_custom_models(in_arg['arch'], in_arg['arch_type'], NUM_CLASSES, in_arg['feature_extract'], 
                               in_arg['hidden_units'], use_pretrained=True)
print(model_ft)
#GPU or CPU Agnostic handling. Use GPU if available
if torch.cuda.is_available():
    device = torch.device("cuda:0")
    in_arg['gpu'] = 'gpu'
else:
    device = in_arg['gpu'] = 'cpu'
# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_ft = model_ft.to(device)
print(f"Using {device} device for training/validating")
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.torch/models/vgg16-397923af.pth
# 100%|██████████| 553433881/553433881 [00:05<00:00, 109947387.73it/s]
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (fc1): Linear(in_features=25088, out_features=1024, bias=True)
#     (relu1): ReLU()
#     (drop1): Dropout(p=0.5)
#     (fc2): Linear(in_features=1024, out_features=512, bias=True)
#     (relu2): ReLU()
#     (drop2): Dropout(p=0.5)
#     (fc3): Linear(in_features=512, out_features=256, bias=True)
#     (relu3): ReLU()
#     (drop3): Dropout(p=0.5)
#     (fc_final): Linear(in_features=256, out_features=102, bias=True)
#     (output): LogSoftmax()
#   )
# )
# Using cuda:0 device for training/validating

# %%
#Create Optimizer but first gather parameters to update
params_to_update = model_ft.parameters()
print("Params to learn:")
if in_arg['feature_extract']:
    params_to_update = []
    for name,param in model_ft.named_parameters():
        if param.requires_grad == True:
            params_to_update.append(param)
            print("\t",name)
else:
    for name,param in model_ft.named_parameters():
        if param.requires_grad == True:
            print("\t",name)
# Observe that all parameters are being optimized
optimizer_ft = optim.Adam(params_to_update, lr=in_arg['learning_rate']) #

#Set Loss criterion
criterion = nn.NLLLoss() #nn.CrossEntropyLoss() #Potential Hyperparameter
# Out:
# Params to learn:
# 	 classifier.fc1.weight
# 	 classifier.fc1.bias
# 	 classifier.fc2.weight
# 	 classifier.fc2.bias
# 	 classifier.fc3.weight
# 	 classifier.fc3.bias
# 	 classifier.fc_final.weight
# 	 classifier.fc_final.bias

# %%
# TODO: Build and train your network
epochs = in_arg['epochs']
steps = 0
running_loss = 0
print_every = 5
for epoch in range(epochs):
    for inputs, labels in trainloaders:
        steps += 1
        # Move input and label tensors to the default device
        inputs, labels = inputs.to(device), labels.to(device)
        
        logps = model_ft(inputs) #model.forward(inputs)
        loss = criterion(logps, labels)
        
        optimizer_ft.zero_grad()
        loss.backward()
        optimizer_ft.step()

        running_loss += loss.item()
        
        if steps % print_every == 0:
            test_loss = 0
            accuracy = 0
            model_ft.eval()
            with torch.no_grad():
                for inputs, labels in testloaders:
                    inputs, labels = inputs.to(device), labels.to(device)
                    logps = model_ft.forward(inputs)
                    batch_loss = criterion(logps, labels)
                    
                    test_loss += batch_loss.item()
                    
                    # Calculate accuracy
                    ps = torch.exp(logps)
                    top_p, top_class = ps.topk(1, dim=1)
                    equals = top_class == labels.view(*top_class.shape)
                    accuracy += torch.mean(equals.type(torch.FloatTensor)).item()
                    
            print(f"Epoch {epoch+1}/{epochs}.. "
                  f"Train loss: {running_loss/print_every:.3f}.. "
                  f"Test loss: {test_loss/len(testloaders):.3f}.. "
                  f"Test accuracy: {accuracy/len(testloaders):.3f}")
            running_loss = 0
            model_ft.train()
# Out:
# Epoch 1/10.. Train loss: 5.182.. Test loss: 4.550.. Test accuracy: 0.028
# Epoch 1/10.. Train loss: 4.709.. Test loss: 4.522.. Test accuracy: 0.020
# Epoch 1/10.. Train loss: 4.607.. Test loss: 4.505.. Test accuracy: 0.056
# Epoch 1/10.. Train loss: 4.541.. Test loss: 4.510.. Test accuracy: 0.055
# Epoch 1/10.. Train loss: 4.591.. Test loss: 4.479.. Test accuracy: 0.075
# Epoch 1/10.. Train loss: 4.577.. Test loss: 4.438.. Test accuracy: 0.067
# Epoch 1/10.. Train loss: 4.503.. Test loss: 4.376.. Test accuracy: 0.070
# Epoch 1/10.. Train loss: 4.554.. Test loss: 4.368.. Test accuracy: 0.103
# Epoch 1/10.. Train loss: 4.569.. Test loss: 4.388.. Test accuracy: 0.092
# Epoch 1/10.. Train loss: 4.489.. Test loss: 4.297.. Test accuracy: 0.087
# Epoch 1/10.. Train loss: 4.384.. Test loss: 4.212.. Test accuracy: 0.119
# Epoch 1/10.. Train loss: 4.411.. Test loss: 4.147.. Test accuracy: 0.132
# Epoch 1/10.. Train loss: 4.299.. Test loss: 4.036.. Test accuracy: 0.129
# Epoch 1/10.. Train loss: 4.476.. Test loss: 4.115.. Test accuracy: 0.145
# Epoch 1/10.. Train loss: 4.220.. Test loss: 3.945.. Test accuracy: 0.133
# Epoch 1/10.. Train loss: 4.357.. Test loss: 3.930.. Test accuracy: 0.150
# Epoch 1/10.. Train loss: 4.143.. Test loss: 3.880.. Test accuracy: 0.165
# Epoch 1/10.. Train loss: 4.321.. Test loss: 3.811.. Test accuracy: 0.208
# Epoch 1/10.. Train loss: 4.115.. Test loss: 3.684.. Test accuracy: 0.218
# Epoch 1/10.. Train loss: 4.056.. Test loss: 3.528.. Test accuracy: 0.185
# Epoch 2/10.. Train loss: 4.182.. Test loss: 3.583.. Test accuracy: 0.190
# Epoch 2/10.. Train loss: 4.188.. Test loss: 3.658.. Test accuracy: 0.182
# Epoch 2/10.. Train loss: 4.047.. Test loss: 3.562.. Test accuracy: 0.203
# Epoch 2/10.. Train loss: 3.914.. Test loss: 3.377.. Test accuracy: 0.208
# Epoch 2/10.. Train loss: 4.088.. Test loss: 3.355.. Test accuracy: 0.218
# Epoch 2/10.. Train loss: 4.089.. Test loss: 3.493.. Test accuracy: 0.218
# Epoch 2/10.. Train loss: 4.087.. Test loss: 3.456.. Test accuracy: 0.209
# Epoch 2/10.. Train loss: 4.171.. Test loss: 3.472.. Test accuracy: 0.218
# Epoch 2/10.. Train loss: 3.987.. Test loss: 3.396.. Test accuracy: 0.215
# Epoch 2/10.. Train loss: 4.042.. Test loss: 3.399.. Test accuracy: 0.237
# Epoch 2/10.. Train loss: 4.002.. Test loss: 3.369.. Test accuracy: 0.216
# Epoch 2/10.. Train loss: 4.169.. Test loss: 3.242.. Test accuracy: 0.242
# Epoch 2/10.. Train loss: 3.946.. Test loss: 3.312.. Test accuracy: 0.260
# Epoch 2/10.. Train loss: 4.017.. Test loss: 3.394.. Test accuracy: 0.247
# Epoch 2/10.. Train loss: 3.915.. Test loss: 3.314.. Test accuracy: 0.275
# Epoch 2/10.. Train loss: 4.001.. Test loss: 3.282.. Test accuracy: 0.255
# Epoch 2/10.. Train loss: 3.848.. Test loss: 3.348.. Test accuracy: 0.233
# Epoch 2/10.. Train loss: 4.112.. Test loss: 3.330.. Test accuracy: 0.253
# Epoch 2/10.. Train loss: 4.066.. Test loss: 3.353.. Test accuracy: 0.265
# Epoch 2/10.. Train loss: 4.057.. Test loss: 3.351.. Test accuracy: 0.239
# Epoch 2/10.. Train loss: 3.921.. Test loss: 3.290.. Test accuracy: 0.243
# Epoch 3/10.. Train loss: 4.038.. Test loss: 3.314.. Test accuracy: 0.232
# Epoch 3/10.. Train loss: 3.991.. Test loss: 3.284.. Test accuracy: 0.235
# Epoch 3/10.. Train loss: 4.113.. Test loss: 3.197.. Test accuracy: 0.228
# Epoch 3/10.. Train loss: 3.720.. Test loss: 3.222.. Test accuracy: 0.235
# Epoch 3/10.. Train loss: 4.015.. Test loss: 3.237.. Test accuracy: 0.228
# Epoch 3/10.. Train loss: 3.975.. Test loss: 3.257.. Test accuracy: 0.221
# Epoch 3/10.. Train loss: 3.652.. Test loss: 3.181.. Test accuracy: 0.251
# Epoch 3/10.. Train loss: 4.130.. Test loss: 3.182.. Test accuracy: 0.262
# Epoch 3/10.. Train loss: 3.784.. Test loss: 3.282.. Test accuracy: 0.252
# Epoch 3/10.. Train loss: 3.964.. Test loss: 3.331.. Test accuracy: 0.245
# Epoch 3/10.. Train loss: 3.902.. Test loss: 3.376.. Test accuracy: 0.251
# Epoch 3/10.. Train loss: 3.857.. Test loss: 3.297.. Test accuracy: 0.240
# Epoch 3/10.. Train loss: 3.886.. Test loss: 3.160.. Test accuracy: 0.273
# Epoch 3/10.. Train loss: 3.984.. Test loss: 3.162.. Test accuracy: 0.282
# Epoch 3/10.. Train loss: 4.044.. Test loss: 3.057.. Test accuracy: 0.307
# Epoch 3/10.. Train loss: 4.108.. Test loss: 3.112.. Test accuracy: 0.272
# Epoch 3/10.. Train loss: 3.944.. Test loss: 3.204.. Test accuracy: 0.246
# Epoch 3/10.. Train loss: 3.902.. Test loss: 3.174.. Test accuracy: 0.246
# Epoch 3/10.. Train loss: 3.980.. Test loss: 3.210.. Test accuracy: 0.245
# Epoch 3/10.. Train loss: 3.898.. Test loss: 3.120.. Test accuracy: 0.272
# Epoch 4/10.. Train loss: 3.902.. Test loss: 3.088.. Test accuracy: 0.252
# Epoch 4/10.. Train loss: 3.821.. Test loss: 3.092.. Test accuracy: 0.243
# Epoch 4/10.. Train loss: 3.848.. Test loss: 3.025.. Test accuracy: 0.259
# Epoch 4/10.. Train loss: 4.099.. Test loss: 3.160.. Test accuracy: 0.259
# Epoch 4/10.. Train loss: 3.774.. Test loss: 3.076.. Test accuracy: 0.273
# Epoch 4/10.. Train loss: 3.828.. Test loss: 3.079.. Test accuracy: 0.258
# Epoch 4/10.. Train loss: 3.838.. Test loss: 3.110.. Test accuracy: 0.255
# Epoch 4/10.. Train loss: 4.018.. Test loss: 3.149.. Test accuracy: 0.257
# Epoch 4/10.. Train loss: 3.990.. Test loss: 3.205.. Test accuracy: 0.254
# Epoch 4/10.. Train loss: 3.937.. Test loss: 3.162.. Test accuracy: 0.252
# Epoch 4/10.. Train loss: 3.893.. Test loss: 3.154.. Test accuracy: 0.245
# Epoch 4/10.. Train loss: 3.995.. Test loss: 3.075.. Test accuracy: 0.277
# Epoch 4/10.. Train loss: 3.656.. Test loss: 3.050.. Test accuracy: 0.265
# Epoch 4/10.. Train loss: 4.038.. Test loss: 3.050.. Test accuracy: 0.265
# Epoch 4/10.. Train loss: 4.004.. Test loss: 3.081.. Test accuracy: 0.281
# Epoch 4/10.. Train loss: 4.166.. Test loss: 3.130.. Test accuracy: 0.270
# Epoch 4/10.. Train loss: 3.804.. Test loss: 3.110.. Test accuracy: 0.259
# Epoch 4/10.. Train loss: 3.842.. Test loss: 3.067.. Test accuracy: 0.258
# Epoch 4/10.. Train loss: 3.879.. Test loss: 3.102.. Test accuracy: 0.254
# Epoch 4/10.. Train loss: 3.832.. Test loss: 3.141.. Test accuracy: 0.252
# Epoch 4/10.. Train loss: 3.931.. Test loss: 3.114.. Test accuracy: 0.267
# Epoch 5/10.. Train loss: 3.849.. Test loss: 3.064.. Test accuracy: 0.270
# Epoch 5/10.. Train loss: 3.814.. Test loss: 3.060.. Test accuracy: 0.275
# Epoch 5/10.. Train loss: 3.963.. Test loss: 3.078.. Test accuracy: 0.243
# Epoch 5/10.. Train loss: 3.876.. Test loss: 3.065.. Test accuracy: 0.275
# Epoch 5/10.. Train loss: 3.843.. Test loss: 3.107.. Test accuracy: 0.267
# Epoch 5/10.. Train loss: 4.028.. Test loss: 3.187.. Test accuracy: 0.259
# Epoch 5/10.. Train loss: 4.082.. Test loss: 3.165.. Test accuracy: 0.246
# Epoch 5/10.. Train loss: 3.811.. Test loss: 3.064.. Test accuracy: 0.262
# Epoch 5/10.. Train loss: 3.829.. Test loss: 3.089.. Test accuracy: 0.236
# Epoch 5/10.. Train loss: 3.989.. Test loss: 3.110.. Test accuracy: 0.246
# Epoch 5/10.. Train loss: 3.684.. Test loss: 3.007.. Test accuracy: 0.278
# Epoch 5/10.. Train loss: 3.742.. Test loss: 2.940.. Test accuracy: 0.300
# Epoch 5/10.. Train loss: 4.061.. Test loss: 2.934.. Test accuracy: 0.292
# Epoch 5/10.. Train loss: 3.817.. Test loss: 2.922.. Test accuracy: 0.280
# Epoch 5/10.. Train loss: 3.905.. Test loss: 2.931.. Test accuracy: 0.287
# Epoch 5/10.. Train loss: 3.788.. Test loss: 2.962.. Test accuracy: 0.279
# Epoch 5/10.. Train loss: 3.822.. Test loss: 2.975.. Test accuracy: 0.266
# Epoch 5/10.. Train loss: 4.127.. Test loss: 2.971.. Test accuracy: 0.278
# Epoch 5/10.. Train loss: 3.795.. Test loss: 2.990.. Test accuracy: 0.282
# Epoch 5/10.. Train loss: 3.771.. Test loss: 2.962.. Test accuracy: 0.294
# Epoch 5/10.. Train loss: 3.782.. Test loss: 2.917.. Test accuracy: 0.301
# Epoch 6/10.. Train loss: 4.018.. Test loss: 2.929.. Test accuracy: 0.311
# Epoch 6/10.. Train loss: 3.799.. Test loss: 2.942.. Test accuracy: 0.293
# Epoch 6/10.. Train loss: 3.809.. Test loss: 2.944.. Test accuracy: 0.270
# Epoch 6/10.. Train loss: 3.743.. Test loss: 2.993.. Test accuracy: 0.239
# Epoch 6/10.. Train loss: 3.843.. Test loss: 3.076.. Test accuracy: 0.243
# Epoch 6/10.. Train loss: 3.841.. Test loss: 3.051.. Test accuracy: 0.244
# Epoch 6/10.. Train loss: 3.668.. Test loss: 2.977.. Test accuracy: 0.271
# Epoch 6/10.. Train loss: 3.854.. Test loss: 2.966.. Test accuracy: 0.276
# Epoch 6/10.. Train loss: 3.762.. Test loss: 2.934.. Test accuracy: 0.289
# Epoch 6/10.. Train loss: 4.269.. Test loss: 3.024.. Test accuracy: 0.297
# Epoch 6/10.. Train loss: 3.781.. Test loss: 2.995.. Test accuracy: 0.289
# Epoch 6/10.. Train loss: 3.665.. Test loss: 2.935.. Test accuracy: 0.278
# Epoch 6/10.. Train loss: 3.886.. Test loss: 2.934.. Test accuracy: 0.286
# Epoch 6/10.. Train loss: 4.006.. Test loss: 2.969.. Test accuracy: 0.278
# Epoch 6/10.. Train loss: 3.800.. Test loss: 2.990.. Test accuracy: 0.240
# Epoch 6/10.. Train loss: 3.968.. Test loss: 3.033.. Test accuracy: 0.234
# Epoch 6/10.. Train loss: 3.933.. Test loss: 2.942.. Test accuracy: 0.250
# Epoch 6/10.. Train loss: 3.873.. Test loss: 2.947.. Test accuracy: 0.268
# Epoch 6/10.. Train loss: 3.926.. Test loss: 2.982.. Test accuracy: 0.264
# Epoch 6/10.. Train loss: 3.750.. Test loss: 2.992.. Test accuracy: 0.281
# Epoch 7/10.. Train loss: 4.024.. Test loss: 3.013.. Test accuracy: 0.295
# Epoch 7/10.. Train loss: 3.786.. Test loss: 3.037.. Test accuracy: 0.285
# Epoch 7/10.. Train loss: 3.884.. Test loss: 2.999.. Test accuracy: 0.258
# Epoch 7/10.. Train loss: 3.858.. Test loss: 3.021.. Test accuracy: 0.258
# Epoch 7/10.. Train loss: 3.790.. Test loss: 2.997.. Test accuracy: 0.274
# Epoch 7/10.. Train loss: 3.715.. Test loss: 2.925.. Test accuracy: 0.259
# Epoch 7/10.. Train loss: 3.852.. Test loss: 2.868.. Test accuracy: 0.270
# Epoch 7/10.. Train loss: 3.882.. Test loss: 2.880.. Test accuracy: 0.286
# Epoch 7/10.. Train loss: 3.845.. Test loss: 2.935.. Test accuracy: 0.275
# Epoch 7/10.. Train loss: 3.605.. Test loss: 2.915.. Test accuracy: 0.269
# Epoch 7/10.. Train loss: 3.552.. Test loss: 2.905.. Test accuracy: 0.273
# Epoch 7/10.. Train loss: 3.815.. Test loss: 2.926.. Test accuracy: 0.252
# Epoch 7/10.. Train loss: 3.797.. Test loss: 2.878.. Test accuracy: 0.263
# Epoch 7/10.. Train loss: 3.748.. Test loss: 2.846.. Test accuracy: 0.264
# Epoch 7/10.. Train loss: 3.740.. Test loss: 2.795.. Test accuracy: 0.284
# Epoch 7/10.. Train loss: 3.858.. Test loss: 2.848.. Test accuracy: 0.276
# Epoch 7/10.. Train loss: 3.751.. Test loss: 2.836.. Test accuracy: 0.292
# Epoch 7/10.. Train loss: 3.747.. Test loss: 2.836.. Test accuracy: 0.292
# Epoch 7/10.. Train loss: 3.873.. Test loss: 2.816.. Test accuracy: 0.310
# Epoch 7/10.. Train loss: 3.732.. Test loss: 2.810.. Test accuracy: 0.297
# Epoch 7/10.. Train loss: 3.726.. Test loss: 2.881.. Test accuracy: 0.280
# Epoch 8/10.. Train loss: 3.823.. Test loss: 2.858.. Test accuracy: 0.271
# Epoch 8/10.. Train loss: 4.044.. Test loss: 2.833.. Test accuracy: 0.290
# Epoch 8/10.. Train loss: 3.978.. Test loss: 2.820.. Test accuracy: 0.296
# Epoch 8/10.. Train loss: 3.666.. Test loss: 2.791.. Test accuracy: 0.295
# Epoch 8/10.. Train loss: 3.782.. Test loss: 2.805.. Test accuracy: 0.293
# Epoch 8/10.. Train loss: 3.859.. Test loss: 2.864.. Test accuracy: 0.278
# Epoch 8/10.. Train loss: 3.763.. Test loss: 2.896.. Test accuracy: 0.287
# Epoch 8/10.. Train loss: 3.880.. Test loss: 2.894.. Test accuracy: 0.278
# Epoch 8/10.. Train loss: 3.690.. Test loss: 2.863.. Test accuracy: 0.293
# Epoch 8/10.. Train loss: 3.533.. Test loss: 2.841.. Test accuracy: 0.305
# Epoch 8/10.. Train loss: 3.909.. Test loss: 2.828.. Test accuracy: 0.284
# Epoch 8/10.. Train loss: 3.660.. Test loss: 2.803.. Test accuracy: 0.285
# Epoch 8/10.. Train loss: 3.803.. Test loss: 2.847.. Test accuracy: 0.290
# Epoch 8/10.. Train loss: 3.811.. Test loss: 2.863.. Test accuracy: 0.307
# Epoch 8/10.. Train loss: 3.639.. Test loss: 2.889.. Test accuracy: 0.321
# Epoch 8/10.. Train loss: 3.764.. Test loss: 2.843.. Test accuracy: 0.317
# Epoch 8/10.. Train loss: 3.863.. Test loss: 2.854.. Test accuracy: 0.293
# Epoch 8/10.. Train loss: 3.762.. Test loss: 2.874.. Test accuracy: 0.285
# Epoch 8/10.. Train loss: 3.719.. Test loss: 2.854.. Test accuracy: 0.293
# Epoch 8/10.. Train loss: 3.692.. Test loss: 2.794.. Test accuracy: 0.308
# Epoch 9/10.. Train loss: 3.710.. Test loss: 2.783.. Test accuracy: 0.315
# Epoch 9/10.. Train loss: 3.681.. Test loss: 2.771.. Test accuracy: 0.304
# Epoch 9/10.. Train loss: 3.504.. Test loss: 2.794.. Test accuracy: 0.293
# Epoch 9/10.. Train loss: 3.583.. Test loss: 2.795.. Test accuracy: 0.284
# Epoch 9/10.. Train loss: 3.449.. Test loss: 2.759.. Test accuracy: 0.304
# Epoch 9/10.. Train loss: 3.717.. Test loss: 2.677.. Test accuracy: 0.339
# Epoch 9/10.. Train loss: 3.873.. Test loss: 2.700.. Test accuracy: 0.334
# Epoch 9/10.. Train loss: 3.861.. Test loss: 2.770.. Test accuracy: 0.317
# Epoch 9/10.. Train loss: 3.494.. Test loss: 2.785.. Test accuracy: 0.310
# Epoch 9/10.. Train loss: 3.734.. Test loss: 2.786.. Test accuracy: 0.304
# Epoch 9/10.. Train loss: 3.616.. Test loss: 2.788.. Test accuracy: 0.298
# Epoch 9/10.. Train loss: 3.645.. Test loss: 2.761.. Test accuracy: 0.297
# Epoch 9/10.. Train loss: 3.713.. Test loss: 2.696.. Test accuracy: 0.316
# Epoch 9/10.. Train loss: 4.027.. Test loss: 2.694.. Test accuracy: 0.333
# Epoch 9/10.. Train loss: 3.615.. Test loss: 2.765.. Test accuracy: 0.315
# Epoch 9/10.. Train loss: 3.944.. Test loss: 2.846.. Test accuracy: 0.301
# Epoch 9/10.. Train loss: 3.961.. Test loss: 2.930.. Test accuracy: 0.272
# Epoch 9/10.. Train loss: 3.517.. Test loss: 2.927.. Test accuracy: 0.275
# Epoch 9/10.. Train loss: 3.530.. Test loss: 2.880.. Test accuracy: 0.277
# Epoch 9/10.. Train loss: 3.706.. Test loss: 2.838.. Test accuracy: 0.291
# Epoch 9/10.. Train loss: 3.751.. Test loss: 2.826.. Test accuracy: 0.305
# Epoch 10/10.. Train loss: 3.581.. Test loss: 2.851.. Test accuracy: 0.288
# Epoch 10/10.. Train loss: 3.609.. Test loss: 2.866.. Test accuracy: 0.289
# Epoch 10/10.. Train loss: 3.613.. Test loss: 2.781.. Test accuracy: 0.298
# Epoch 10/10.. Train loss: 3.646.. Test loss: 2.714.. Test accuracy: 0.320
# Epoch 10/10.. Train loss: 3.469.. Test loss: 2.686.. Test accuracy: 0.325
# Epoch 10/10.. Train loss: 3.660.. Test loss: 2.700.. Test accuracy: 0.307
# Epoch 10/10.. Train loss: 3.849.. Test loss: 2.727.. Test accuracy: 0.325
# Epoch 10/10.. Train loss: 3.784.. Test loss: 2.803.. Test accuracy: 0.305
# Epoch 10/10.. Train loss: 3.622.. Test loss: 2.874.. Test accuracy: 0.295
# Epoch 10/10.. Train loss: 3.402.. Test loss: 2.846.. Test accuracy: 0.281
# Epoch 10/10.. Train loss: 3.626.. Test loss: 2.817.. Test accuracy: 0.277
# Epoch 10/10.. Train loss: 3.542.. Test loss: 2.797.. Test accuracy: 0.277
# Epoch 10/10.. Train loss: 3.736.. Test loss: 2.780.. Test accuracy: 0.283
# Epoch 10/10.. Train loss: 3.733.. Test loss: 2.762.. Test accuracy: 0.309
# Epoch 10/10.. Train loss: 3.651.. Test loss: 2.780.. Test accuracy: 0.305
# Epoch 10/10.. Train loss: 3.617.. Test loss: 2.798.. Test accuracy: 0.286
# Epoch 10/10.. Train loss: 3.451.. Test loss: 2.773.. Test accuracy: 0.301
# Epoch 10/10.. Train loss: 3.857.. Test loss: 2.742.. Test accuracy: 0.319
# Epoch 10/10.. Train loss: 3.618.. Test loss: 2.737.. Test accuracy: 0.317
# Epoch 10/10.. Train loss: 3.708.. Test loss: 2.734.. Test accuracy: 0.322
# Epoch 10/10.. Train loss: 3.577.. Test loss: 2.737.. Test accuracy: 0.325

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
#First, define the function to validate/test on testing set
def validate(model, criterion, testing_set):
    accuracy = 0
    test_loss = 0
    model.eval() # Evaluation mode
    with torch.no_grad():
        for images, labels in testing_set:
            
            images = images.to(device)
            labels = labels.to(device)

            output = model(images) #model.forward(images)
            test_loss += criterion(output, labels).item()

            # Take exponential to get log softmax probibilities
            probs = torch.exp(output)

            # highest probability is the predicted class
            # compare with true label
            correct_predictions = (labels.data == probs.max(1)[1])

            # Turn ByteTensor into np_array to calculate mean
            accuracy += np.array(correct_predictions).mean()
    
#     model.train() # Switch training mode back on
    
    return test_loss/len(testing_set), accuracy/len(testing_set)

# %%
#Then, call the function and test
# TODO: Do validation on the test set
test_loss, accuracy = validate(model_ft, criterion, testloaders)
print("Network preformance on test dataset-------------")
print("Accuracy on test dataset: {:.2f}%".format(accuracy*100))
# Out:
# Network preformance on test dataset-------------
# Accuracy on test dataset: 32.46%

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
print("Our model: \n\n", model_ft, '\n')
print("The state dict keys: \n\n", model_ft.state_dict().keys())
# Out:
# Our model:
#
#  VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (fc1): Linear(in_features=25088, out_features=1024, bias=True)
#     (relu1): ReLU()
#     (drop1): Dropout(p=0.5)
#     (fc2): Linear(in_features=1024, out_features=512, bias=True)
#     (relu2): ReLU()
#     (drop2): Dropout(p=0.5)
#     (fc3): Linear(in_features=512, out_features=256, bias=True)
#     (relu3): ReLU()
#     (drop3): Dropout(p=0.5)
#     (fc_final): Linear(in_features=256, out_features=102, bias=True)
#     (output): LogSoftmax()
#   )
# )
#
# The state dict keys:
#
#  odict_keys(['features.0.weight', 'features.0.bias', 'features.2.weight', 'features.2.bias', 'features.5.weight', 'features.5.bias', 'features.7.weight', 'features.7.bias', 'features.10.weight', 'features.10.bias', 'features.12.weight', 'features.12.bias', 'features.14.weight', 'features.14.bias', 'features.17.weight', 'features.17.bias', 'features.19.weight', 'features.19.bias', 'features.21.weight', 'features.21.bias', 'features.24.weight', 'features.24.bias', 'features.26.weight', 'features.26.bias', 'features.28.weight', 'features.28.bias', 'classifier.fc1.weight', 'classifier.fc1.bias', 'classifier.fc2.weight', 'classifier.fc2.bias', 'classifier.fc3.weight', 'classifier.fc3.bias', 'classifier.fc_final.weight', 'classifier.fc_final.bias'])

# %%
# TODO: Save the checkpoint
checkpoint = {'arch': in_arg['arch'],
              'arch_type': in_arg['arch_type'],
              'class_to_idx' : train_data.class_to_idx,
              'state_dict': model_ft.state_dict(),
              'hidden_units': in_arg['hidden_units'],
              'num_classes' : NUM_CLASSES,
              'feature_extract' : in_arg['feature_extract'],
              'gpu_or_cpu' : in_arg['gpu']
             }
torch.save(checkpoint, 'checkpoint.pth')
print(f"Saved checkpoint as checkpoint.pth")
# Out:
# Saved checkpoint as checkpoint.pth

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
#GPU/CPU Agnostic Code
if torch.cuda.is_available():
    device = torch.device("cuda")
    checkpoint = torch.load('checkpoint.pth')
else:
    device = "cpu"
    checkpoint = torch.load('checkpoint.pth', map_location = device)
print(f"Using {device} device for predicting/inference")

if checkpoint['arch_type'] == 'custom':
    model_ft = build_custom_models(checkpoint['arch'], checkpoint['arch_type'], len(checkpoint['class_to_idx']), checkpoint['feature_extract'], 
                                   checkpoint['hidden_units'], use_pretrained=True)
else:
    print("Nothing to predict")
    exit()
     
model_ft.class_to_idx = checkpoint['class_to_idx']
model_ft.gpu_or_cpu = checkpoint['gpu_or_cpu']
model_ft.load_state_dict(checkpoint['state_dict'])
model_ft.to(device)
# Out:
# Using cuda device for predicting/inference
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (fc1): Linear(in_features=25088, out_features=1024, bias=True)
#     (relu1): ReLU()
#     (drop1): Dropout(p=0.5)
#     (fc2): Linear(in_features=1024, out_features=512, bias=True)
#     (relu2): ReLU()
#     (drop2): Dropout(p=0.5)
#     (fc3): Linear(in_features=512, out_features=256, bias=True)
#     (relu3): ReLU()
#     (drop3): Dropout(p=0.5)
#     (fc_final): Linear(in_features=256, out_features=102, bias=True)
#     (output): LogSoftmax()
#   )
# )

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %% [markdown]
# ## Sample Display of Original Flower (Neither Actual Label or a Prediction)

# %%
#Choose and display flower as-is before any transformation
image = 'flowers/test/1/image_06743.jpg' #next(iter(testloaders))
display(Image.open(image))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x601 at 0x7FA26F434390>

# %%
def process_image(image_path):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    # TODO: Process a PIL image for use in a PyTorch model
   
    im = Image.open(image_path)
    
    # Resize the image
    if im.size[1] < im.size[0]:
        im.thumbnail((255, math.pow(255, 2)))
    else:
        im.thumbnail((math.pow(255, 2), 255))    
    #im_resized = im.resize((256, 256))
        
    #Crop image
    width, height = im.size
    left = (width - 224)/2
    top = (height - 224)/2
    right = (width + 224)/2
    bottom = (height + 224)/2
    im = im.crop((left, top, right, bottom))
    
    #turn into np.array and standardize
    np_image = np.array(im)/255
    
    #undo mean, std and then transpose
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])    
    np_image = (np_image - mean)/ std
    np_image = np.transpose(np_image, (2, 0, 1))
    return np_image

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.transpose((1, 2, 0)) #image.numpy().transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    ax.set_title(title)
    
    return ax

# %% [markdown]
# ## Sample Display of Transformed Flower (Neither Actual Label or a Prediction)

# %%
#Test the function above after Transformation
imshow(process_image(image), title = 'Testing display of flower using imshow() function after Transformation')

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    
    # TODO: Implement the code to predict the class from an image file
    
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    model.to(device)
    model.eval()
    
    tensor_img = torch.FloatTensor([process_image(image_path)])
    #print(tensor_img.unsqueeze(0).shape)
    tensor_img = tensor_img.to(device)
    log_ps = model(tensor_img) #unsqueeze(0)
    #print(log_ps.shape)
    result = log_ps.topk(topk)
    ps = torch.exp(result[0].data).cpu().numpy()[0] #gpu
    #print(ps.shape)
    #print("Between")
    #ps = torch.exp(result[0].data).numpy()[0] #cpu
    #print(ps.shape)
    
    idxs = result[1].data.cpu().numpy()[0]
    #idxs = result[1].data.numpy()[0]
    return (ps, idxs)

# %%
# Get the probabilties and indices from passing the image through the model
probs, idxs = predict(image, model_ft)
print(f"Probabilities are {probs}")
print(f"Indexes are {idxs} which need to be converted to classes which need to converted to class or species name")
# Out:
# Probabilities are [ 0.0324015   0.03003449  0.024976    0.02409843  0.02315244]
# Indexes are [49 84 74 90 40] which need to be converted to classes which need to converted to class or species name

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# !ls flowers/test/*
# Out:
# flowers/test/1:
# image_06743.jpg  image_06754.jpg  image_06764.jpg
# image_06752.jpg  image_06760.jpg
#
# flowers/test/10:
# image_07090.jpg  image_07104.jpg  image_07117.jpg
#
# flowers/test/100:
# image_07896.jpg  image_07899.jpg  image_07926.jpg  image_07938.jpg
# image_07897.jpg  image_07902.jpg  image_07936.jpg  image_07939.jpg
#
# flowers/test/101:
# image_07949.jpg  image_07952.jpg  image_07983.jpg  image_07988.jpg
#
# flowers/test/102:
# image_08004.jpg  image_08015.jpg  image_08030.jpg
# image_08012.jpg  image_08023.jpg  image_08042.jpg
#
# flowers/test/11:
# image_03098.jpg  image_03141.jpg  image_03165.jpg
# image_03115.jpg  image_03147.jpg  image_03176.jpg
# image_03130.jpg  image_03151.jpg  image_03177.jpg
#
# flowers/test/12:
# image_03994.jpg  image_04014.jpg  image_04052.jpg
# image_03996.jpg  image_04016.jpg  image_04059.jpg
# image_04012.jpg  image_04023.jpg  image_04077.jpg
#
# flowers/test/13:
# image_05745.jpg  image_05767.jpg  image_05775.jpg
# image_05761.jpg  image_05769.jpg  image_05787.jpg
#
# flowers/test/14:
# image_06052.jpg  image_06083.jpg  image_06091.jpg
#
# flowers/test/15:
# image_06351.jpg  image_06360.jpg  image_06369.jpg  image_06374.jpg
#
# flowers/test/16:
# image_06657.jpg  image_06670.jpg  image_06673.jpg
#
# flowers/test/17:
# image_03830.jpg  image_03861.jpg  image_03893.jpg
# image_03846.jpg  image_03864.jpg  image_03906.jpg
# image_03855.jpg  image_03872.jpg  image_03911.jpg
#
# flowers/test/18:
# image_04254.jpg  image_04272.jpg  image_04292.jpg
# image_04256.jpg  image_04277.jpg  image_04322.jpg
#
# flowers/test/19:
# image_06155.jpg  image_06170.jpg  image_06186.jpg  image_06197.jpg
# image_06159.jpg  image_06175.jpg  image_06196.jpg
#
# flowers/test/2:
# image_05100.jpg  image_05109.jpg  image_05133.jpg
# image_05107.jpg  image_05125.jpg
#
# flowers/test/20:
# image_04910.jpg  image_04912.jpg  image_04938.jpg
#
# flowers/test/21:
# image_06805.jpg  image_06807.jpg
#
# flowers/test/22:
# image_05360.jpg  image_05362.jpg  image_05366.jpg  image_05391.jpg
#
# flowers/test/23:
# image_03382.jpg  image_03409.jpg  image_03440.jpg  image_03454.jpg
# image_03390.jpg  image_03414.jpg  image_03442.jpg
#
# flowers/test/24:
# image_06815.jpg  image_06849.jpg
#
# flowers/test/25:
# image_06580.jpg  image_06583.jpg  image_06611.jpg
# image_06582.jpg  image_06593.jpg
#
# flowers/test/26:
# image_06497.jpg  image_06500.jpg  image_06526.jpg
# image_06498.jpg  image_06514.jpg
#
# flowers/test/27:
# image_06864.jpg  image_06871.jpg  image_06887.jpg
#
# flowers/test/28:
# image_05214.jpg  image_05242.jpg  image_05270.jpg
# image_05230.jpg  image_05253.jpg  image_05277.jpg
#
# flowers/test/29:
# image_04083.jpg  image_04112.jpg  image_04142.jpg
# image_04090.jpg  image_04124.jpg  image_04145.jpg
# image_04095.jpg  image_04137.jpg  image_04146.jpg
#
# flowers/test/3:
# image_06634.jpg  image_06641.jpg
#
# flowers/test/30:
# image_03466.jpg  image_03488.jpg  image_03510.jpg  image_03541.jpg
# image_03481.jpg  image_03489.jpg  image_03512.jpg  image_03542.jpg
# image_03482.jpg  image_03506.jpg  image_03528.jpg
# image_03484.jpg  image_03509.jpg  image_03538.jpg
#
# flowers/test/31:
# image_06903.jpg  image_08070.jpg
#
# flowers/test/32:
# image_05591.jpg  image_05595.jpg  image_05610.jpg
# image_05592.jpg  image_05602.jpg  image_05614.jpg
#
# flowers/test/33:
# image_06454.jpg  image_06457.jpg  image_06470.jpg  image_06479.jpg
# image_06456.jpg  image_06460.jpg  image_06478.jpg  image_06486.jpg
#
# flowers/test/34:
# image_06929.jpg  image_06941.jpg  image_06961.jpg
# image_06933.jpg  image_06954.jpg
#
# flowers/test/35:
# image_06984.jpg  image_06992.jpg  image_08084.jpg
# image_06986.jpg  image_07006.jpg  image_08088.jpg
#
# flowers/test/36:
# image_04334.jpg  image_04364.jpg  image_04382.jpg  image_04400.jpg
# image_04344.jpg  image_04373.jpg  image_04392.jpg
#
# flowers/test/37:
# image_03734.jpg  image_03783.jpg  image_03807.jpg  image_03815.jpg
# image_03741.jpg  image_03789.jpg  image_03811.jpg  image_03821.jpg
#
# flowers/test/38:
# image_05796.jpg  image_05799.jpg  image_05812.jpg  image_05825.jpg
# image_05797.jpg  image_05806.jpg  image_05824.jpg  image_05833.jpg
#
# flowers/test/39:
# image_07010.jpg  image_07018.jpg  image_07043.jpg
# image_07016.jpg  image_07035.jpg
#
# flowers/test/4:
# image_05636.jpg  image_05640.jpg  image_05658.jpg
# image_05637.jpg  image_05653.jpg  image_05678.jpg
#
# flowers/test/40:
# image_04563.jpg  image_04573.jpg  image_04586.jpg  image_04588.jpg
# image_04568.jpg  image_04582.jpg  image_04587.jpg  image_04609.jpg
#
# flowers/test/41:
# image_02193.jpg  image_02245.jpg  image_02263.jpg  image_02305.jpg
# image_02200.jpg  image_02251.jpg  image_02266.jpg  image_02306.jpg
# image_02222.jpg  image_02257.jpg  image_02270.jpg
# image_02237.jpg  image_02261.jpg  image_02302.jpg
#
# flowers/test/42:
# image_05696.jpg  image_05711.jpg  image_05730.jpg  image_05731.jpg
#
# flowers/test/43:
# image_02329.jpg  image_02365.jpg  image_02386.jpg  image_02426.jpg
# image_02335.jpg  image_02369.jpg  image_02394.jpg  image_02431.jpg
# image_02346.jpg  image_02370.jpg  image_02400.jpg  image_02433.jpg
# image_02349.jpg  image_02371.jpg  image_02412.jpg  image_02435.jpg
#
# flowers/test/44:
# image_01502.jpg  image_01516.jpg  image_01530.jpg  image_01564.jpg
# image_01512.jpg  image_01518.jpg  image_01548.jpg  image_01578.jpg
# image_01515.jpg  image_01527.jpg  image_01560.jpg
#
# flowers/test/45:
# image_07139.jpg  image_07140.jpg  image_07142.jpg
#
# flowers/test/46:
# image_00958.jpg  image_00996.jpg  image_01071.jpg  image_01115.jpg
# image_00961.jpg  image_00999.jpg  image_01077.jpg  image_01119.jpg
# image_00969.jpg  image_01003.jpg  image_01078.jpg  image_01125.jpg
# image_00970.jpg  image_01026.jpg  image_01090.jpg
# image_00976.jpg  image_01038.jpg  image_01092.jpg
# image_00990.jpg  image_01061.jpg  image_01109.jpg
#
# flowers/test/47:
# image_04966.jpg  image_04993.jpg  image_05013.jpg
#
# flowers/test/48:
# image_04627.jpg  image_04665.jpg  image_04671.jpg
# image_04663.jpg  image_04667.jpg
#
# flowers/test/49:
# image_06202.jpg  image_06213.jpg  image_06215.jpg
#
# flowers/test/5:
# image_05159.jpg  image_05166.jpg  image_05169.jpg  image_05186.jpg
#
# flowers/test/50:
# image_06297.jpg  image_06319.jpg  image_06321.jpg  image_06546.jpg
# image_06318.jpg  image_06320.jpg  image_06541.jpg  image_06547.jpg
#
# flowers/test/51:
# image_01314.jpg  image_01370.jpg  image_01474.jpg  image_03973.jpg
# image_01316.jpg  image_01388.jpg  image_03926.jpg  image_03980.jpg
# image_01328.jpg  image_01406.jpg  image_03939.jpg  image_03984.jpg
# image_01335.jpg  image_01407.jpg  image_03954.jpg  image_03985.jpg
# image_01340.jpg  image_01457.jpg  image_03960.jpg  image_03986.jpg
# image_01362.jpg  image_01468.jpg  image_03968.jpg  image_03989.jpg
#
# flowers/test/52:
# image_04160.jpg  image_04168.jpg  image_04181.jpg  image_04221.jpg
# image_04167.jpg  image_04169.jpg  image_04200.jpg  image_04240.jpg
#
# flowers/test/53:
# image_03645.jpg  image_03662.jpg  image_03689.jpg  image_03718.jpg
# image_03649.jpg  image_03669.jpg  image_03712.jpg  image_03724.jpg
# image_03652.jpg  image_03672.jpg  image_03714.jpg
# image_03653.jpg  image_03677.jpg  image_03717.jpg
#
# flowers/test/54:
# image_05402.jpg  image_05413.jpg  image_05430.jpg  image_05440.jpg
#
# flowers/test/55:
# image_04701.jpg  image_04731.jpg  image_04740.jpg  image_04747.jpg
# image_04707.jpg  image_04733.jpg  image_04742.jpg
#
# flowers/test/56:
# image_02772.jpg  image_02785.jpg  image_02821.jpg  image_02841.jpg
# image_02779.jpg  image_02808.jpg  image_02825.jpg  image_02844.jpg
#
# flowers/test/57:
# image_07234.jpg  image_07250.jpg  image_08127.jpg  image_08134.jpg
# image_07241.jpg  image_07266.jpg  image_08129.jpg  image_08144.jpg
# image_07242.jpg  image_07267.jpg  image_08133.jpg
#
# flowers/test/58:
# image_02663.jpg  image_02687.jpg  image_02721.jpg  image_02743.jpg
# image_02672.jpg  image_02694.jpg  image_02722.jpg  image_02752.jpg
# image_02677.jpg  image_02695.jpg  image_02737.jpg
# image_02681.jpg  image_02719.jpg  image_02738.jpg
#
# flowers/test/59:
# image_05020.jpg  image_05038.jpg  image_05052.jpg  image_05067.jpg
# image_05033.jpg  image_05039.jpg  image_05064.jpg
#
# flowers/test/6:
# image_07173.jpg  image_07185.jpg  image_07199.jpg
# image_07181.jpg  image_07191.jpg  image_08106.jpg
# image_07182.jpg  image_07198.jpg  image_08108.jpg
#
# flowers/test/60:
# image_02932.jpg  image_02971.jpg  image_02987.jpg  image_03026.jpg
# image_02933.jpg  image_02977.jpg  image_03000.jpg
# image_02958.jpg  image_02978.jpg  image_03008.jpg
#
# flowers/test/61:
# image_06248.jpg  image_06251.jpg  image_06271.jpg  image_06284.jpg
# image_06249.jpg  image_06266.jpg  image_06279.jpg  image_06290.jpg
#
# flowers/test/62:
# image_07269.jpg  image_07276.jpg  image_08172.jpg  image_08177.jpg
#
# flowers/test/63:
# image_05875.jpg  image_05878.jpg  image_05882.jpg  image_05890.jpg
#
# flowers/test/64:
# image_06099.jpg  image_06130.jpg  image_06138.jpg
# image_06104.jpg  image_06134.jpg
#
# flowers/test/65:
# image_03188.jpg  image_03211.jpg  image_03252.jpg  image_03269.jpg
# image_03197.jpg  image_03243.jpg  image_03258.jpg
#
# flowers/test/66:
# image_05537.jpg  image_05549.jpg  image_05562.jpg  image_05582.jpg
#
# flowers/test/67:
# image_07056.jpg  image_07079.jpg  image_07080.jpg  image_07082.jpg
#
# flowers/test/68:
# image_05903.jpg  image_05927.jpg  image_05956.jpg
#
# flowers/test/69:
# image_05959.jpg  image_05971.jpg  image_05994.jpg
#
# flowers/test/7:
# image_07211.jpg  image_07218.jpg  image_08099.jpg
# image_07215.jpg  image_07219.jpg  image_08104.jpg
#
# flowers/test/70:
# image_05308.jpg  image_05324.jpg  image_05330.jpg  image_05331.jpg
#
# flowers/test/71:
# image_04482.jpg  image_04514.jpg  image_04524.jpg
# image_04488.jpg  image_04515.jpg  image_04555.jpg
# image_04512.jpg  image_04519.jpg  image_04557.jpg
#
# flowers/test/72:
# image_03547.jpg  image_03599.jpg  image_03624.jpg  image_03633.jpg
# image_03575.jpg  image_03603.jpg  image_03625.jpg  image_03635.jpg
# image_03593.jpg  image_03613.jpg  image_03628.jpg
#
# flowers/test/73:
# image_00258.jpg  image_00294.jpg  image_00337.jpg  image_00389.jpg
# image_00260.jpg  image_00303.jpg  image_00345.jpg  image_00394.jpg
# image_00277.jpg  image_00319.jpg  image_00349.jpg  image_00400.jpg
# image_00282.jpg  image_00320.jpg  image_00353.jpg  image_00401.jpg
# image_00284.jpg  image_00324.jpg  image_00365.jpg  image_00409.jpg
# image_00288.jpg  image_00330.jpg  image_00369.jpg  image_00426.jpg
# image_00291.jpg  image_00335.jpg  image_00387.jpg  image_00445.jpg
#
# flowers/test/74:
# image_01151.jpg  image_01200.jpg  image_01254.jpg  image_01307.jpg
# image_01165.jpg  image_01209.jpg  image_01256.jpg  image_01312.jpg
# image_01173.jpg  image_01213.jpg  image_01276.jpg
# image_01191.jpg  image_01249.jpg  image_01305.jpg
#
# flowers/test/75:
# image_02075.jpg  image_02111.jpg  image_02144.jpg  image_02188.jpg
# image_02078.jpg  image_02115.jpg  image_02154.jpg
# image_02085.jpg  image_02119.jpg  image_02157.jpg
# image_02088.jpg  image_02135.jpg  image_02167.jpg
#
# flowers/test/76:
# image_02472.jpg  image_02479.jpg  image_02484.jpg  image_02550.jpg
#
# flowers/test/77:
# image_00005.jpg  image_00065.jpg  image_00177.jpg  image_00222.jpg
# image_00006.jpg  image_00092.jpg  image_00187.jpg  image_00239.jpg
# image_00024.jpg  image_00099.jpg  image_00191.jpg  image_00248.jpg
# image_00025.jpg  image_00114.jpg  image_00202.jpg  image_00251.jpg
# image_00029.jpg  image_00116.jpg  image_00203.jpg
# image_00050.jpg  image_00132.jpg  image_00204.jpg
# image_00060.jpg  image_00176.jpg  image_00212.jpg
#
# flowers/test/78:
# image_01830.jpg  image_01856.jpg  image_01903.jpg  image_01949.jpg
# image_01843.jpg  image_01874.jpg  image_01919.jpg  image_01953.jpg
# image_01848.jpg  image_01888.jpg  image_01928.jpg
# image_01855.jpg  image_01893.jpg  image_01931.jpg
#
# flowers/test/79:
# image_06708.jpg  image_06720.jpg  image_06726.jpg
#
# flowers/test/8:
# image_03291.jpg  image_03314.jpg  image_03347.jpg  image_03364.jpg
# image_03295.jpg  image_03319.jpg  image_03357.jpg
# image_03299.jpg  image_03320.jpg  image_03359.jpg
#
# flowers/test/80:
# image_01983.jpg  image_01996.jpg  image_02041.jpg  image_02055.jpg
# image_01990.jpg  image_02020.jpg  image_02049.jpg  image_02062.jpg
# image_01993.jpg  image_02023.jpg  image_02051.jpg
#
# flowers/test/81:
# image_00798.jpg  image_00825.jpg  image_00869.jpg  image_00946.jpg
# image_00814.jpg  image_00826.jpg  image_00888.jpg
# image_00815.jpg  image_00828.jpg  image_00898.jpg
# image_00818.jpg  image_00833.jpg  image_00926.jpg
#
# flowers/test/82:
# image_01594.jpg  image_01610.jpg  image_01661.jpg  image_01685.jpg
# image_01598.jpg  image_01614.jpg  image_01662.jpg  image_01686.jpg
# image_01599.jpg  image_01618.jpg  image_01666.jpg
# image_01603.jpg  image_01650.jpg  image_01672.jpg
# image_01609.jpg  image_01653.jpg  image_01679.jpg
#
# flowers/test/83:
# image_01735.jpg  image_01755.jpg  image_01777.jpg  image_01810.jpg
# image_01737.jpg  image_01759.jpg  image_01789.jpg  image_01818.jpg
# image_01742.jpg  image_01770.jpg  image_01805.jpg
# image_01748.jpg  image_01774.jpg  image_01809.jpg
#
# flowers/test/84:
# image_02557.jpg  image_02572.jpg  image_02583.jpg  image_02615.jpg
# image_02563.jpg  image_02576.jpg  image_02586.jpg
# image_02568.jpg  image_02581.jpg  image_02613.jpg
#
# flowers/test/85:
# image_04786.jpg  image_04805.jpg  image_04810.jpg  image_04825.jpg
# image_04797.jpg  image_04806.jpg  image_04814.jpg
# image_04801.jpg  image_04808.jpg  image_04819.jpg
#
# flowers/test/86:
# image_02865.jpg  image_02893.jpg  image_02912.jpg
# image_02873.jpg  image_02910.jpg
#
# flowers/test/87:
# image_05462.jpg  image_05469.jpg  image_05488.jpg
# image_05466.jpg  image_05485.jpg  image_05493.jpg
#
# flowers/test/88:
# image_00457.jpg  image_00482.jpg  image_00551.jpg  image_00594.jpg
# image_00467.jpg  image_00520.jpg  image_00563.jpg
# image_00474.jpg  image_00526.jpg  image_00582.jpg
# image_00477.jpg  image_00540.jpg  image_00584.jpg
#
# flowers/test/89:
# image_00610.jpg  image_00654.jpg  image_00724.jpg  image_00755.jpg
# image_00617.jpg  image_00676.jpg  image_00726.jpg  image_00756.jpg
# image_00634.jpg  image_00699.jpg  image_00740.jpg  image_00779.jpg
# image_00645.jpg  image_00708.jpg  image_00745.jpg
#
# flowers/test/9:
# image_06410.jpg  image_06413.jpg
#
# flowers/test/90:
# image_04405.jpg  image_04426.jpg  image_04432.jpg  image_04469.jpg
# image_04407.jpg  image_04428.jpg  image_04458.jpg  image_04473.jpg
# image_04417.jpg  image_04430.jpg  image_04459.jpg
# image_04420.jpg  image_04431.jpg  image_04468.jpg
#
# flowers/test/91:
# image_04851.jpg  image_04860.jpg  image_04875.jpg  image_04890.jpg
# image_04856.jpg  image_04870.jpg  image_04883.jpg  image_08061.jpg
#
# flowers/test/92:
# image_03032.jpg  image_03044.jpg  image_03052.jpg  image_03058.jpg
# image_03039.jpg  image_03048.jpg  image_03054.jpg  image_03075.jpg
# image_03041.jpg  image_03049.jpg  image_03056.jpg
#
# flowers/test/93:
# image_06014.jpg  image_06021.jpg  image_06033.jpg
# image_06017.jpg  image_06031.jpg  image_06037.jpg
#
# flowers/test/94:
# image_07308.jpg  image_07352.jpg  image_07370.jpg  image_07400.jpg
# image_07327.jpg  image_07357.jpg  image_07388.jpg  image_07415.jpg
# image_07333.jpg  image_07358.jpg  image_07395.jpg  image_07434.jpg
# image_07346.jpg  image_07361.jpg  image_07399.jpg  image_07436.jpg
#
# flowers/test/95:
# image_07468.jpg  image_07505.jpg  image_07536.jpg  image_07573.jpg
# image_07470.jpg  image_07508.jpg  image_07550.jpg  image_07584.jpg
# image_07472.jpg  image_07514.jpg  image_07551.jpg
# image_07487.jpg  image_07519.jpg  image_07561.jpg
#
# flowers/test/96:
# image_07596.jpg  image_07622.jpg  image_07672.jpg
# image_07597.jpg  image_07646.jpg  image_07676.jpg
# image_07606.jpg  image_07668.jpg  image_07683.jpg
#
# flowers/test/97:
# image_07696.jpg  image_07709.jpg  image_07737.jpg
# image_07708.jpg  image_07719.jpg
#
# flowers/test/98:
# image_07753.jpg  image_07758.jpg  image_07777.jpg  image_07787.jpg
#
# flowers/test/99:
# image_07833.jpg  image_07840.jpg  image_07857.jpg  image_07874.jpg
# image_07838.jpg  image_07854.jpg  image_07871.jpg

# %% [markdown]
# ## Actual Label (Species of Flower) - PROVIDE YOUR INPUT FLOWER NAME/PATH

# %%
test_image_path = test_dir + '/12/image_03994.jpg' #UPDATE THIS FOR PREDICTION
test_image_name = cat_to_name[os.path.basename(os.path.dirname(test_image_path))]
                              
# Show the image for reference
imshow(process_image(test_image_path), title=test_image_name)

# %% [markdown]
# ## Predicted Label (Species of Flower)

# %%
# TODO: Display an image along with the top 5 classes
# Get the probabilties and indices from passing the image through the model
probs, idxs = predict(test_image_path, model_ft)

# Swap the keys and values in class_to_idx so that
# indices can be mapped to original classes in dataset
idx_to_class = {v: k for k, v in model_ft.class_to_idx.items()}

# Map the classes to flower category lables                              
names = list(map(lambda x: cat_to_name.get(f"{idx_to_class[x]}",'Unknown'), idxs))

# Display top 5 most probable flower categories                               
y_pos = np.arange(len(names))
plt.barh(y_pos, probs)
plt.yticks(y_pos, names)
plt.gca().invert_yaxis()
 
plt.show()

# %% [markdown]
# <font color='red'>**Reminder for Workspace users:** If your network becomes very large when saved as a checkpoint, there might be issues with saving backups in your workspace. You should reduce the size of your hidden layers and train again.
#
# We strongly encourage you to delete these large interim files and directories before navigating to another page or closing the browser tab.</font>

# %%
# TODO remove .pth files or move it to a temporary `~/opt` directory in this Workspace
